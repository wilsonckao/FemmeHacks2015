# %% [markdown]
# <a href="https://colab.research.google.com/github/wilsonckao/FemmeHacks2015/blob/master/coolclass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
print('NLTK imported successfully')
# Out:
# NLTK imported successfully

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt')

sentence = "hi this is going to be an amazing day. i am going to learn about nlp"

word_tokenize(sentence)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ['hi',
#  'this',
#  'is',
#  'going',
#  'to',
#  'be',
#  'an',
#  'amazing',
#  'day',
#  '.',
#  'i',
#  'am',
#  'going',
#  'to',
#  'learn',
#  'about',
#  'nlp']

# %%
from nltk import PunktSentenceTokenizer
nltk.download('punkt')

sentence = "hi. today is going to be an amazing day. i am going to learn about nlp."

pt = PunktSentenceTokenizer()
pt.tokenize(sentence)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['hi.',
#  'today is going to be an amazing day.',
#  'i am going to learn about nlp.']

# %%
from nltk.corpus import stopwords
nltk.download('stopwords') #Downloading the sotp words

print(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ...

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

example_sent = "this is a sample sentence, just ot show that stop words can be removed. no messing"

stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(example_sent)
filtered_sentence = []

for w in word_tokens:
  if w not in stop_words:
    filtered_sentence.append(w)

    print(word_tokens)
    print(filtered_sentence)
    
    #['this', 'is', 'a', 'sample', 'sentence', ',', 'just', 'ot', 'show', 'that', 'stop', 'words', 'can', 'be', 'removed', '.', 'no', 'messing']
['sample']
['this', 'is', 'a', 'sample', 'sentence', ',', 'just', 'ot', 'show', 'that', 'stop', 'words', 'can', 'be', 'removed', '.', 'no', 'messing']
['sample', 'sentence']
['this', 'is', 'a', 'sample', 'sentence', ',', 'just', 'ot', 'show', 'that', 'stop', 'words', 'can', 'be', 'removed', '.', 'no', 'messing']
['sample', 'sentence', ',']
['this', 'is', 'a', 'sample', 'sentence', ',', 'just', 'ot', 'show', 'that', 'stop', 'words', 'can', 'be', 'removed', '.', 'no', 'messing']
['sample', 'sentence', ',', 'ot']
['this', 'is', 'a', 'sample', 'sentence', ',', 'just', 'ot', 'show', 'that', 'stop', 'words', 'can', 'be', 'removed', '.', 'no', 'messing']
['sample', 'sentence', ',', 'ot', 'show']
['this', 'is', 'a', 'sample', 'sentence', ',', 'just', 'ot', 'show', 'that', 'stop', 'words', 'can', 'be', 'removed', '.', 'no', 'messing']
['sample', 'sentence', ',', 'ot', 'show', 'stop']
['this', 'is', 'a', 'sample', 'sentence', ',', 'just', 'ot', 'show', 'that', 'stop', 'words', 'can', 'be', 'removed', '.', 'no', 'messing']
['sample', 'sentence', ',', 'ot', 'show', 'stop', 'words']
['this', 'is', 'a', 'sample', 'sentence', ',', 'just', 'ot', 'show', 'that', 'stop', 'words', 'can', 'be', 'removed', '.', 'no', 'messing']
['sample', 'sentence', ',', 'ot', 'show', 'stop', 'words', 'removed']
['this', 'is', 'a', 'sample', 'sentence', ',', 'just', 'ot', 'show', 'that', 'stop', 'words', 'can', 'be', 'removed', '.', 'no', 'messing']
['sample', 'sentence', ',', 'ot', 'show', 'stop', 'words', 'removed', '.']
['this', 'is', 'a', 'sample', 'sentence', ',', 'just', 'ot', 'show', 'that', 'stop', 'words', 'can', 'be', 'removed', '.', 'no', 'messing']
['sample', 'sentence', ',', 'ot', 'show', 'stop', 'words', 'removed', '.', 'messing']
# Out:
# ['this', 'is', 'a', 'sample', 'sentence', ',', 'just', 'ot', 'show', 'that', 'stop', 'words', 'can', 'be', 'removed', '.', 'no', 'messing']
# ['sample']
# ['this', 'is', 'a', 'sample', 'sentence', ',', 'just', 'ot', 'show', 'that', 'stop', 'words', 'can', 'be', 'removed', '.', 'no', 'messing']
# ['sample', 'sentence']
# ['this', 'is', 'a', 'sample', 'sentence', ',', 'just', 'ot', 'show', 'that', 'stop', 'words', 'can', 'be', 'removed', '.', 'no', 'messing']
# ['sample', 'sentence', ',']
# ['this', 'is', 'a', 'sample', 'sentence', ',', 'just', 'ot', 'show', 'that', 'stop', 'words', 'can', 'be', 'removed', '.', 'no', 'messing']
# ['sample', 'sentence', ',', 'ot']
# ['this', 'is', 'a', 'sample', 'sentence', ',', 'just', 'ot', 'show', 'that', 'stop', 'words', 'can', 'be', 'removed', '.', 'no', 'messing']
# ['sample', 'sentence', ',', 'ot', 'show']
# ['this', 'is', 'a', 'sample', 'sentence', ',', 'just', 'ot', 'show', 'that', 'stop', 'words', 'can', 'be', 'removed', '.', 'no', 'messing']
# ...

# %%
import nltk
example_words = ["game", "gaming","gamed","games"]
ps = nltk.PorterStemmer()

for word in example_words:
  print(word+':' +ps.stem(word))
# Out:
# game:game
# gaming:game
# gamed:game
# games:game

# %%
from nltk import word_tokenize, pos_tag
nltk.download('punkt') 
nltk.download('averaged_perceptron_tagger')

sentence = "Singapore is a very good learning platform, do you agree"

sen_token = word_tokenize(sentence)
pos_tag(sen_token)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [('Singapore', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('very', 'RB'),
#  ('good', 'JJ'),
#  ('learning', 'NN'),
#  ('platform', 'NN'),
#  (',', ','),
#  ('do', 'VBP'),
#  ('you', 'PRP'),
#  ('agree', 'VB')]

# %%
nltk.download('tagsets')
nltk.help.upenn_tagset()
# Out:
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets.zip.
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
# ...

# %%
sample_sent = 'the beach silso lay on the sunset side of singapore, as red and ragged as a cloud'

list(nltk.bigrams(sample_sent.split()))
# Out:
# [('the', 'beach'),
#  ('beach', 'silso'),
#  ('silso', 'lay'),
#  ('lay', 'on'),
#  ('on', 'the'),
#  ('the', 'sunset'),
#  ('sunset', 'side'),
#  ('side', 'of'),
#  ('of', 'singapore,'),
#  ('singapore,', 'as'),
#  ('as', 'red'),
#  ('red', 'and'),
#  ('and', 'ragged'),
#  ('ragged', 'as'),
#  ('as', 'a'),
#  ('a', 'cloud')]

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
doc =nlp('european authorities fined google for a record 5.1 billion on wednesday for abusing its power')
print(doc)
print([(X.text, X.label_) for X in doc.ents])
# Out:
# european authorities fined google for a record 5.1 billion on wednesday for abusing its power
# [('a record 5.1 billion', 'MONEY'), ('wednesday', 'DATE')]

# %%
displacy.render(doc, jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5">european authorities fined google for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     a record 5.1 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  for abusing its power</div>

# %%
from pprint import pprint
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA
nltk.download('vader_lexicon')

lines = ['the news at the hospital was not good',
       'i just bought a new bike and i am very happy',
        'i just bought bread.'
       ]
sia =SIA()
results = []

for line in lines:
  pol_score = sia.polarity_scores(line)
  pol_score['headline'] = line
  results.append(pol_score)
  
  pprint(results[:3])
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [{'compound': -0.3412,
#   'headline': 'the news at the hospital was not good',
#   'neg': 0.256,
#   'neu': 0.744,
#   'pos': 0.0}]
# [{'compound': -0.3412,
#   'headline': 'the news at the hospital was not good',
#   'neg': 0.256,
#   'neu': 0.744,
#   'pos': 0.0},
#  {'compound': 0.6115,
#   'headline': 'i just bought a new bike and i am very happy',
#   'neg': 0.0,
#   'neu': 0.637,
#   'pos': 0.363}]
# [{'compound': -0.3412,
#   'headline': 'the news at the hospital was not good',
#   'neg': 0.256,
#   'neu': 0.744,
#   'pos': 0.0},
#  {'compound': 0.6115,
#   'headline': 'i just bought a new bike and i am very happy',
#   'neg': 0.0,
#   'neu': 0.637,
#   'pos': 0.363},
#  {'compound': 0.0,
#   'headline': 'i just bought bread.',
#   'neg': 0.0,
#   'neu': 1.0,
#   'pos': 0.0}]

# %%
# !pip install langdetect
from langdetect import detect
print(detect("this is an aenglish sentence"))
# Out:
# ...
# en

# %%
# !pip install textstat
from textstat.textstate import textstat

example_paragraph = "also, keep watching through to the end, because after" "encouraging words of my own to essentially contradict"

print(textstate.text_standard(example_paragraph))
# Out:
# ...
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-1a10f3592def> in <module>()
#       1 get_ipython().system('pip install textstat')
# ----> 2 from textstat.textstate import textstat
#       3
#       4 example_paragraph = "also, keep watching through to the end, because after" "encouraging words of my own to essentially contradict"
#       5
#
# ModuleNotFoundError: No module named 'textstat.textstate'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install fuzzywuzzy
from fuzzywuzzy import fuzz

fuzz.ratio("this is sentence one", "is this sentencetwo?")
# Out:
# ...
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# 75

# %%
# !pip install wordcloud

from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = "this is a very random random random text text because i just just"

wordcloud = WordCloud().generate(text)

plt.imshow(wordcloud)
plt.axis("off")
# Out:
# ...
# (-0.5, 399.5, 199.5, -0.5)

# %%
from nltk.corpus import brown
import nltk
nltk.download('brown')

brown.readme().replace('\n','')
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# 'BROWN CORPUSA Standard Corpus of Present-Day Edited AmericanEnglish, for use with Digital Computers.by W. N. Francis and H. Kucera (1964)Department of Linguistics, Brown UniversityProvidence, Rhode Island, USARevised 1971, Revised and Amplified 1979http://www.hit.uib.no/icame/brown/bcm.htmlDistributed with the permission of the copyright holder,redistribution permitted.'

# %%
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
from nltk import FreqDist
words_in_corpora = FreqDist(w.lower() for w in brown.words() if w.isalpha())
words_in_corpora_freq_sorted = list(map(list, words_in_corpora.items()))

words_in_corpora
# Out:
# FreqDist({'the': 69971,
#           'fulton': 17,
#           'county': 155,
#           'grand': 48,
#           'jury': 67,
#           'said': 1961,
#           'friday': 60,
#           'an': 3740,
#           'investigation': 51,
#           'of': 36412,
#           'recent': 179,
#           'primary': 96,
#           'election': 77,
#           'produced': 90,
#           'no': 2139,
#           'evidence': 204,
#           'that': 10594,
#           'any': 1344,
#           'irregularities': 8,
#           'took': 426,
#           'place': 570,
#           'further': 218,
#           'in': 21337,
#           'presentments': 1,
#           'city': 393,
#           'executive': 55,
#           'committee': 168,
#           'which': 3561,
#           'had': 5133,
#           'charge': 122,
#           'deserves': 16,
#           'praise': 17,
#           'and': 28853,
#           'thanks': 37,
#           'atlanta': 35,
#           'for': 9489,
#           'manner': 124,
# ...

# %%
from nltk import FreqDist
words_in_corpora = FreqDist(w.lower() for w in brown.words() if w.isalpha())
words_in_corpora_freq_sorted = list(map(list, words_in_corpora.items()))

words_in_corpora_freq_sorted.sort(key=lambda x: x[1], reverse=True)
words_in_corpora_freq_sorted[0:5]
# Out:
# [['the', 69971], ['of', 36412], ['and', 28853], ['to', 26158], ['a', 23195]]

# %%
best1500 = words_in_corpora_freq_sorted[:1500]

for list_item in best1500:
  del list_item[1]
  
import itertools

chain = itertools.chain(*best1500)

best1500 = list(chain)

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

stopw = stopwords.words('english')

def nonstop(listwords):
  return [word for word in listwords if word not in stopw]

best1500_words_corpora = nonstop(best1500)
best1500_words_corpora
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['one',
#  'would',
#  'said',
#  'new',
#  'could',
#  'time',
#  'two',
#  'may',
#  'first',
#  'like',
#  'man',
#  'even',
#  'made',
#  'also',
#  'many',
#  'must',
#  'af',
#  'back',
#  'years',
#  'much',
#  'way',
#  'well',
#  'people',
#  'little',
#  'state',
#  'good',
#  'make',
#  'world',
#  'still',
#  'see',
#  'men',
#  'work',
#  'long',
#  'get',
#  'life',
#  'never',
#  'day',
#  'another',
#  'know',
#  'last',
#  'us',
#  'might',
#  'great',
#  'old',
#  'year',
#  'come',
#  'since',
#  'go',
#  'came',
#  'right',
#  'used',
#  'take',
#  'three',
#  'states',
#  'house',
#  'use',
#  'without',
#  'place',
#  'american',
#  'around',
#  'however',
#  'home',
#  'small',
#  'found',
#  'thought',
#  'went',
#  'say',
#  'part',
#  'general',
#  'high',
#  'upon',
#  'school',
#  'every',
#  'got',
#  'united',
#  'left',
# ...

# %%
documents = [([item.lower() for item
              in nonstop(brown.words(fileid))
              if item.isalpha()],category)
            for category in brown.categories()
            for fileid in brown.fileids(category)]
documents[0]
# Out:
# (['dan',
#   'morgan',
#   'told',
#   'would',
#   'forget',
#   'ann',
#   'turner',
#   'he',
#   'well',
#   'rid',
#   'he',
#   'certainly',
#   'want',
#   'wife',
#   'fickle',
#   'ann',
#   'if',
#   'married',
#   'asking',
#   'trouble',
#   'but',
#   'rationalization',
#   'sometimes',
#   'woke',
#   'middle',
#   'night',
#   'thinking',
#   'ann',
#   'could',
#   'get',
#   'back',
#   'sleep',
#   'his',
#   'plans',
#   'dreams',
#   'revolved',
#   'around',
#   'much',
#   'long',
#   'felt',
#   'nothing',
#   'the',
#   'easiest',
#   'thing',
#   'would',
#   'sell',
#   'al',
#   'budd',
#   'leave',
#   'country',
#   'stubborn',
#   'streak',
#   'allow',
#   'the',
#   'best',
#   'antidote',
#   'bitterness',
#   'disappointment',
#   'poisoned',
#   'hard',
#   'work',
#   'he',
#   'found',
#   'tired',
#   'enough',
#   'night',
#   'went',
#   'sleep',
#   'simply',
#   'exhausted',
#   'stay',
#   'awake',
#   'each',
#   'day',
#   'found',
# ...

# %%
from random import shuffle

shuffle(documents)
documents[0]
# Out:
# (['about',
#   'north',
#   'providence',
#   'taxpayers',
#   'made',
#   'appeals',
#   'board',
#   'tax',
#   'assessors',
#   'review',
#   'tax',
#   'assessments',
#   'last',
#   'two',
#   'days',
#   'town',
#   'hall',
#   'centredale',
#   'these',
#   'last',
#   'two',
#   'days',
#   'set',
#   'aside',
#   'board',
#   'hearing',
#   'appeals',
#   'appeals',
#   'heard',
#   'two',
#   'days',
#   'two',
#   'weeks',
#   'ago',
#   'about',
#   'persons',
#   'appeared',
#   'time',
#   'louis',
#   'grenier',
#   'clerk',
#   'board',
#   'said',
#   'appeals',
#   'reviewed',
#   'december',
#   'time',
#   'board',
#   'visiting',
#   'new',
#   'construction',
#   'sites',
#   'town',
#   'assessment',
#   'purposes',
#   'they',
#   'also',
#   'visit',
#   'properties',
#   'appeals',
#   'made',
#   'any',
#   'adjustments',
#   'made',
#   'grenier',
#   'said',
#   'earlier',
#   'month',
#   'appear',
#   'balance',
#   'tax',
#   'bill',
#   'since',
# ...

# %%
def document_features(doc):
  doc_set_words = set(doc)
  features_dic = {}
  for word in best1500_words_corpora:
    features_dic['has(%s)' % word] = (word in doc_set_words)
    return features_dic
  
doc_features_set = [(document_features(d),c) for (d,c) in documents]
doc_features_set[0:1]
# Out:
# [({'has(one)': True}, 'news')]

# %%
from nltk import NaiveBayesClassifier

train_set = doc_features_set[:350]
test_set = doc_features_set[350:]

classifier = NaiveBayesClassifier.train(train_set)
classifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#                 has(one) = False          govern : learne =      1.3 : 1.0
#                 has(one) = True           belles : scienc =      1.1 : 1.0

# %%
from nltk.classify import accuracy
print(accuracy(classifier, test_set))
# Out:
# 0.12

# %%
from nltk.tokenize import RegexpTokenizer
text = "God, infintely perfect and blessed in himself, in a plan of sheer"
tokenizer = RegexpTokenizer(r'\w+')
text_tokens = nonstop(tokenizer.tokenize(text.lower()))
text_tokens = [w for w in text_tokens if w.isalpha()]

# %%
text_features = document_features(text_tokens)

# %%
classifier.classify(document_features(text_tokens))
# Out:
# 'learned'

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
import string
import matplotlib.pyplot as plt
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
import time

# !pip install pyLDAvis
import pyLDAvis.sklearn
import os

import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English
# !python -m spacy download en_core_web_lg
# Out:
# ...
#     100% |████████████████████████████████| 1.6MB 15.9MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/98/71/24/513a99e58bb6b8465bae4d2d5e9dba8f0bef8179e3051ac414
# Successfully built pyLDAvis
# ...
#     100% |████████████████████████████████| 852.3MB 95.0MB/s
# ...
#   Running setup.py install for en-core-web-lg ... done
# ...
#
#     Linking successful
#     /usr/local/lib/python3.6/dist-packages/en_core_web_lg -->
#     /usr/local/lib/python3.6/dist-packages/spacy/data/en_core_web_lg
#
#     You can now load the model via spacy.load('en_core_web_lg')

# %%
wines = pd.read_csv('http://bit.ly/usulrn-data')
wines.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
parser = English()
def spacy_tokenizer(sentence):
  mytokens = parser(sentence)
  mytokens = [ word.lemma_.lower().strip()
             if word.lemma_ !="-PRON-" else word.lower_
             for word in mytokens ]
  
  mytokens = [word for word in mytokens if word not in stopwords 
             and word not in punctuations]
  mytokens = " ".join([i for i in mytokens])
  return mytokens

# %%
stopwords = list(STOP_WORDS)
punctuations = string.punctuation
tqdm.pandas()
wines["processed_description"] = wines["description"]
progress_apply(spacy_tokenizer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-85-e98bd295c2df> in <module>()
#       3 tqdm.pandas()
#       4 wines["processed_description"] = wines["description"]
# ----> 5 progress_apply(spacy_tokenizer)
#
# NameError: name 'progress_apply' is not defined

# %%
vectorizer = CountVectorizer(stop_words='english',
                             lowercase=True,
                             token_pattern='[a-zA-Z\-]{2,}')
data_vectorized = vectorizer.fit_transform(wines["processed_description"])

NUM_TOPICS = 10

Ida = LatentDirichletAllocation(n_components=NUM_TOPICS, max_iter=10,
                               learning_method='online',verbose=True)
data_Ida = Ida.fit_transform(data_vectorized)
# Out:
# <input>:3: DeprecationWarning: invalid escape sequence \-
# <input>:3: DeprecationWarning: invalid escape sequence \-
# <input>:3: DeprecationWarning: invalid escape sequence \-
# <input>:3: DeprecationWarning: invalid escape sequence \-
# <input>:3: DeprecationWarning: invalid escape sequence \-
# <input>:3: DeprecationWarning: invalid escape sequence \-
# <input>:3: DeprecationWarning: invalid escape sequence \-
# <input>:3: DeprecationWarning: invalid escape sequence \-
# <input>:3: DeprecationWarning: invalid escape sequence \-
# <input>:3: DeprecationWarning: invalid escape sequence \-
# <input>:3: DeprecationWarning: invalid escape sequence \-
# <input>:3: DeprecationWarning: invalid escape sequence \-
# <input>:3: DeprecationWarning: invalid escape sequence \-
# <input>:3: DeprecationWarning: invalid escape sequence \-
# <input>:3: DeprecationWarning: invalid escape sequence \-
# <input>:3: DeprecationWarning: invalid escape sequence \-
# ...

# %%
def selected_topics(model, vectorizer, top_n=10):
  for idx, topic in enumerate(model.components_):
      print("Topic %d:" % (idx))
      print([(vectorizer.get_feature_names()[i], topic[i])
            for i in topic.argsort()[:-top_n - 1:-1]])
      print("LDA Model:")
      selected_topics(Ida, vectorizer)

# %%
pyLDAvis.enable_notebook()
dash = pyLDAvis.sklearn.prepare(Ida, data_vectorized, vectorizer, mds='tsne')
dash
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics           x           y
# topic
# 0      17.418538        1       1 -110.854424 -221.503555
# 5      15.237569        1       2   90.156883    3.581179
# 6      14.395281        1       3  -16.764086  189.653015
# 1      11.048036        1       4  143.644302 -212.205048
# 9       9.627018        1       5  -51.011112  404.291626
# 7       8.425604        1       6 -338.669800  -37.443390
# 2       8.182828        1       7  309.824585   29.066631
# 4       6.963066        1       8 -124.387314    4.182730
# 8       5.995396        1       9 -258.691589  220.355103
# 3       2.706662        1      10  201.487137  263.157593, topic_info=      Category          Freq         Term         Total  loglift  logprob
# term
# 25194  Default  28667.000000         wine  28667.000000  30.0000  30.0000
# 1132   Default  13008.000000       aromas  13008.000000  29.0000  29.0000
# ...
